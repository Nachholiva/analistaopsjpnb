# %%
import os
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import locale

username = os.getlogin()            
hoy = datetime.datetime.now()
dateformatexport = "%d-%m-%Y"
fecha_actual = hoy.strftime(dateformatexport)

file_path = 'C:\\Users\\dxs81864\\Documents\\Py\\BECH CB\\HITES\\MONTOSCIERRES.csv'
df1 = pd.DataFrame

df = pd.read_table(file_path,
                       names=['monto','dia','lim'],
                       sep=';',
                       header=0)

slims = [df['monto'].min(),df['monto'].max()]
sticks = [90000000,0,-30000000]
ssetticks = np.arange(-400000,100000,100000)
arrmontos = df['monto'].to_numpy()
arrLO = df['lim'].to_numpy()
arrmes = str(df.index)
df['dia'] = pd.to_datetime(df['dia'], format='mixed', dayfirst=True)
locale.setlocale(locale.LC_ALL,'es_CL')
# Out:
# 'es_CL'

# %%
df_mensual = df[df['dia'] > '2023-10-10']
df_mensual = df.set_index('dia')
df_mensual.plot(title='Montos cierres Hites',xlabel='Mes',ylabel='Monto x 1M',figsize=(15,6))
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p:f'{int(x/1000000):,}'))
#plt.gca().xaxis.set_major_formatter(df_mensual.index.ConciseDateFormatter(plt.gca().xaxis.get_major_locator()))
#plt.gca().xaxis.set_major_formatter(df_mensual.index.DateFormatter('%Y-%b'))
myFmt = mdates.DateFormatter('%b/%Y')
plt.gca().xaxis.set_major_formatter(myFmt)
plt.xticks(np.arange('2023-12', '2024-12', dtype='datetime64[M]'),rotation=10, ha='right')
plt.grid(True)
plt.yticks(np.arange(0,41000000,step=2000000))
plt.gca().minorticks_on()
plt.show()
